# %% [markdown]
# **Hand** **Written** **Digit** **Prediction**-**Classification** **Analysis**

# %% [markdown]
# The digit dataset consist of 8x8 pixel images of digits. The images attribute of the dataset of grayscale values for each image. We use arrays to visualize the first 4 images. The target of the dataset stores the digit each image represents

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
